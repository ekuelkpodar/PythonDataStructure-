# %% [markdown]
# **Create Binary Tree**

# %%
class Node:

    def __init__(self, data):

        self.left = None
        self.right = None
        self.data = data

    def insert(self, data):

        if self.data:
          #is the value smaller then then current data
            if data < self.data:
                if self.left is None:
                    self.left = Node(data)
                else:
                    self.left.insert(data)
          #is the value bigger then then current data
            elif data > self.data:
                if self.right is None:
                    self.right = Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data = data

    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print( self.data),
        if self.right:
            self.right.PrintTree()

# %% [markdown]
# **Insert data into the binary treet**

# %%
root = Node(19)
root.insert(4)
root.insert(17)
root.insert(2)

root.PrintTree()
# Out:
# 2
# 4
# 17
# 19
