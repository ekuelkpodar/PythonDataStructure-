# %%
from array import *

data = array('i', [1,2,3,4,5])

for current in data:
 print(current)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Accessing Array Element

# %%
print (data[0])

print (data[2])
# Out:
# 1
# 3

# %% [markdown]
# Inserting Data into Array

# %%
data.insert(1,50)

for x in data:
 print(x)
# Out:
# 1
# 50
# 2
# 3
# 4
# 5

# %% [markdown]
# Delete elements from Array

# %%
data.remove(4)

for x in data:
 print(x)
# Out:
# 1
# 50
# 2
# 3
# 5

# %% [markdown]
# **Search Operation**

# %%
print(data.index(3))
# Out:
# 3

# %% [markdown]
# **Update Operation**

# %%
data[2] = 8

for current  in data:
 print(current)
# Out:
# 1
# 50
# 8
# 3
# 5
