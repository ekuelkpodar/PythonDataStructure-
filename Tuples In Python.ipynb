# %%
tup1 =  ['Math', 'Science', "Gym"]
tup2 = [10, 20, 30, 40, 50, 60, 70 ]
tup3 = "a", "b", "c", "d";

# %% [markdown]
# **list Example in python**

# %%
tup1 = ['Math', 'Science', "Gym"]
tup2 = [10, 20, 30, 40, 50 ]
tup3 = ["a", "b", "c", "d"]

# %% [markdown]
# ****Accessing Values****

# %%
tup1 =  ['Math', 'Science', "Gym"]
tup2 = [10, 20, 30, 40, 50, 60, 70 ]
print("tup1[0]: ", tup1[0])
print("tup2[1:5]: ", tup2[1:5])
# Out:
# tup1[0]:  Math
# tup2[1:5]:  [20, 30, 40, 50]
